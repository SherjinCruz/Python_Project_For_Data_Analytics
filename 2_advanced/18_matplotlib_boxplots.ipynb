# %%
#Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset
from ast import literal_eval

#Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()

#Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills']=df['job_skills'].apply(lambda x:literal_eval(x) if pd.notna(x) else x)

# %%
df_DA_US = df[(df['job_title_short'] =='Data Analyst') & (df['job_country'] == 'United States')].copy()
df_DA_US = df_DA_US.dropna(subset='salary_year_avg')

# %%
df_DA_US['salary_year_avg'].plot(kind='box',vert =False)
plt.xlim(0,250000)
ax=plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x,index: f'${int(x/1000)}k'))
plt.title('Distribution of United States Data Analyst Salary')
plt.xlabel('Yearly Salary')
plt.show()

# %% [markdown]
# ## Comparison of Job Salary using Box Plots

# %%
titles=['Data Scientist','Data Analyst','Data Engineer']
df_DA = df[(df['job_title_short'].isin(titles)) & (df['job_country'] == 'United States')].copy()
df_DA = df_DA.dropna(subset='salary_year_avg')
df_DA
# Out:
#        job_title_short                                          job_title  \
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# 116     Data Scientist                                     Data Scientist
# 146      Data Engineer  Data Engineer Graduate (Real Time Communicatio...
# ...                ...                                                ...
# 785563  Data Scientist  Data Scientist I/II (Model Risk Management & M...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#              job_location                                    job_via  \
# ...

# %%
job_list = [df_DA[df_DA['job_title_short'] == title]['salary_year_avg'] for title in titles]
df = pd.DataFrame(job_list, index=titles,).T
df.boxplot(vert=False)
plt.title('Salary Distribution in United States')
plt.xlabel('Yearly Salary ($USD)')
ax=plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter (lambda x,pos:f'${int(x/1000)}k'))

# %%
ax=plt.gca()
plt.boxplot(job_list,tick_labels=titles,vert=False)
plt.title('Salary Distribution in United States')
plt.xlabel('Yearly Salary ($USD)')
ax.xaxis.set_major_formatter(plt.FuncFormatter (lambda x,pos:f'${int(x/1000)}k'))
plt.xlim(0,600000)
plt.show()

# %%
job_list = [df_DA[df_DA['job_title_short'] == title]['salary_year_avg'] for title in titles]
job_list
# Out:
# [100       228222.0
#  116       114000.0
#  257       103128.0
#  450       157500.0
#  1257       70700.0
#              ...
#  785324    234500.0
#  785488    115000.0
#  785563    136400.0
#  785648    221875.0
#  785692    157500.0
#  Name: salary_year_avg, Length: 4553, dtype: float64,
#  109        89000.0
#  180        90250.0
#  410       133285.0
#  988        62623.0
#  1413       71300.0
#              ...
#  782637     70000.0
#  782798    111175.0
#  783588    125000.0
#  783866    115000.0
#  784882     87500.0
#  Name: salary_year_avg, Length: 4350, dtype: float64,
#  92        120000.0
#  146       129500.0
#  307       185000.0
#  339       195000.0
#  380        97500.0
#              ...
#  783111    125000.0
#  784102     90000.0
#  784191    217500.0
#  785624    139216.0
#  785641    150000.0
#  Name: salary_year_avg, Length: 2915, dtype: float64]

# %%
df = pd.DataFrame(job_list, index=titles)
df
# Out:
#                   100       116       257       450      1257      1543    \
# Data Scientist  228222.0  114000.0  103128.0  157500.0  70700.0  124400.0
# Data Analyst         NaN       NaN       NaN       NaN      NaN       NaN
# Data Engineer        NaN       NaN       NaN       NaN      NaN       NaN
#
#                   1580     2278      2346      2374    ...    779693  \
# Data Scientist  105700.0  95000.0  206500.0  140062.5  ...       NaN
# Data Analyst         NaN      NaN       NaN       NaN  ...       NaN
# Data Engineer        NaN      NaN       NaN       NaN  ...  185000.0
#
#                   780150    780757    781503   781507    783111   784102  \
# Data Scientist       NaN       NaN       NaN      NaN       NaN      NaN
# Data Analyst         NaN       NaN       NaN      NaN       NaN      NaN
# Data Engineer   209000.0  150000.0  175000.0  90000.0  125000.0  90000.0
#
#                   784191    785624    785641
# Data Scientist       NaN       NaN       NaN
# ...
