# %%
#Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

#Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df_original=dataset['train'].to_pandas()

#Data Cleanup
df_original['job_posted_date'] = pd.to_datetime(df_original['job_posted_date'])

# %%
df_original.sample(10)
# Out:
#               job_title_short                                      job_title  \
# 552363           Data Analyst                          Identity Data Analyst
# 588881         Data Scientist                            Lead Data Scientist
# 559755          Data Engineer                     Internship – Data Engineer
# 601814         Data Scientist                             Sr, Data Scientist
# 243283         Data Scientist  Data Science Associate Director, Oncology R&d
# 653929      Software Engineer                       Software Engineer, Japan
# 346305   Senior Data Engineer                Senior Data Engineer (m./w./d.)
# 172005  Senior Data Scientist      Senior Data Scientist, Advanced Analytics
# 518384           Data Analyst              Data Analyst - Replenishment Data
# 207800   Senior Data Engineer                  Sr Data Engineer ( AWS Glue )
#
#                              job_location                        job_via  \
# ...

# %%
df_altered = df_original.copy()

# %%
df_altered
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
hourly_median = df_altered['salary_hour_avg'].median()
yearly_median = df_altered['salary_year_avg'].median()

# %%
df_altered['salary_hour_avg']=df_altered['salary_hour_avg'].fillna(hourly_median)
df_altered['salary_year_avg']=df_altered['salary_year_avg'].fillna(hourly_median)

# %%
df_altered
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df_original
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
id(df_original) == id(df_altered)
# Out:
# False
