# %% [markdown]
# ## Investigate Trending Skills

# %%
#Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset
from ast import literal_eval

#Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()

#Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills']=df['job_skills'].apply(lambda x:literal_eval(x) if pd.notna(x) else x)

# %%
df_DA = df[df['job_title_short'] == 'Data Analyst'].copy()
df_DA['job_posted_month'] = df['job_posted_date'].dt.month
df_DA_explode = df_DA.explode('job_skills')
df_DA_explode
# Out:
#        job_title_short                           job_title  \
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# ...                ...                                 ...
# 785717    Data Analyst  Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
#
#                         job_location                    job_via  \
# 1       Guadalajara, Jalisco, Mexico           via BeBee México
# 1       Guadalajara, Jalisco, Mexico           via BeBee México
# ...

# %%
df_DA_pivot = df_DA_explode.pivot_table(
    index = 'job_posted_month', 
    columns = 'job_skills', aggfunc= 'size', 
    fill_value= 0 )
df_DA_pivot.loc['total_skill_count'] = df_DA_pivot.sum()
df_DA_pivot
# Out:
# job_skills         airflow  airtable  alteryx  angular  angular.js  ansible  \
# job_posted_month
# 1                      197        17      551       63           2       20
# 2                      169         2      448       49           0       14
# 3                      181         4      442       34           0       23
# 4                      155         4      413       22           0       11
# 5                      128         8      310       30           0       19
# 6                      164        14      393       29           0       14
# 7                      207         4      366       15           0        8
# 8                      197         3      413       21           0       12
# 9                      118         4      317       21           0       14
# 10                     173        11      350       40           0       19
# 11                     169         7      293       24           0       19
# ...

# %%
df_DA_series = df_DA_pivot[df_DA_pivot.loc['total_skill_count'].sort_values(ascending=False).index]
df_DA_final = df_DA_series.drop('total_skill_count').iloc[:,:5]
df_DA_final
# Out:
# job_skills          sql  excel  python  tableau  power bi
# job_posted_month
# 1                 11336   8170    6606     5596      4285
# 2                  7947   5772    4751     3936      3307
# 3                  7868   5675    4741     4051      3176
# 4                  7553   5496    4557     3776      3106
# 5                  6617   4773    4070     3245      2695
# 6                  7584   5724    4707     3812      3275
# 7                  7687   5513    4831     3928      3350
# 8                  8823   6482    5576     4533      3859
# 9                  6829   4886    4229     3446      3118
# 10                 7474   5217    4693     3709      3340
# 11                 6652   4776    4233     3284      3012
# 12                 6058   4376    4196     3139      2857

# %%
df_DA_final.plot(kind='line')
plt.title(f'Top 5 skills for data analyst')
plt.xlabel('Job Posted Month')
plt.ylabel('Count')
plt.show()

# %%
df_DA_final=df_DA_final.reset_index()
df_DA_final['job_posted_month_name'] = pd.to_datetime(
    df_DA_final['job_posted_month'],
    format='%m').dt.strftime('%b')
df_DA_final=df_DA_final.set_index('job_posted_month_name')

# %%
df_DA_final
# Out:
# job_skills             job_posted_month    sql  excel  python  tableau  \
# job_posted_month_name
# Jan                                   1  11336   8170    6606     5596
# Feb                                   2   7947   5772    4751     3936
# Mar                                   3   7868   5675    4741     4051
# Apr                                   4   7553   5496    4557     3776
# May                                   5   6617   4773    4070     3245
# Jun                                   6   7584   5724    4707     3812
# Jul                                   7   7687   5513    4831     3928
# Aug                                   8   8823   6482    5576     4533
# Sep                                   9   6829   4886    4229     3446
# Oct                                  10   7474   5217    4693     3709
# Nov                                  11   6652   4776    4233     3284
# Dec                                  12   6058   4376    4196     3139
#
# ...

# %%
df_DA_final.plot(kind='line')
plt.title(f'Top 5 skills for data analyst')
plt.xlabel('Job Posted Month')
plt.ylabel('Count')
plt.show()
